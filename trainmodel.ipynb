# %%
from keras.utils import to_categorical
from keras_preprocessing.image import load_img
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
import os
import pandas as pd
import numpy as np

# %%
TRAIN_DIR = 'images/train'
TEST_DIR = 'images/test'

# %%
def createdataframe(dir):
    image_paths = []
    labels = []
    for label in os.listdir(dir):
        for imagename in os.listdir(os.path.join(dir,label)):
            image_paths.append(os.path.join(dir,label,imagename))
            labels.append(label)
        print(label, "completed")
    return image_paths,labels

# %%
train = pd.DataFrame()
train['image'], train['label'] = createdataframe(TRAIN_DIR)
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed

# %%
print(train)
# Out:
#                                 image     label
# 0            images/train\angry\0.jpg     angry
# 1            images/train\angry\1.jpg     angry
# 2           images/train\angry\10.jpg     angry
# 3        images/train\angry\10002.jpg     angry
# 4        images/train\angry\10016.jpg     angry
# ...                               ...       ...
# 28816  images/train\surprise\9969.jpg  surprise
# 28817  images/train\surprise\9985.jpg  surprise
# 28818  images/train\surprise\9990.jpg  surprise
# 28819  images/train\surprise\9992.jpg  surprise
# 28820  images/train\surprise\9996.jpg  surprise
#
# [28821 rows x 2 columns]

# %%
test = pd.DataFrame()
test['image'], test['label'] = createdataframe(TEST_DIR)
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed

# %%
print(test)
print(test['image'])
# Out:
#                               image     label
# 0       images/test\angry\10052.jpg     angry
# 1       images/test\angry\10065.jpg     angry
# 2       images/test\angry\10079.jpg     angry
# 3       images/test\angry\10095.jpg     angry
# 4       images/test\angry\10121.jpg     angry
# ...                             ...       ...
# 7061  images/test\surprise\9806.jpg  surprise
# 7062  images/test\surprise\9830.jpg  surprise
# 7063  images/test\surprise\9853.jpg  surprise
# 7064  images/test\surprise\9878.jpg  surprise
# 7065   images/test\surprise\993.jpg  surprise
#
# [7066 rows x 2 columns]
# 0         images/test\angry\10052.jpg
# 1         images/test\angry\10065.jpg
# 2         images/test\angry\10079.jpg
# 3         images/test\angry\10095.jpg
# 4         images/test\angry\10121.jpg
#                     ...
# 7061    images/test\surprise\9806.jpg
# 7062    images/test\surprise\9830.jpg
# 7063    images/test\surprise\9853.jpg
# 7064    images/test\surprise\9878.jpg
# 7065     images/test\surprise\993.jpg
# Name: image, Length: 7066, dtype: object

# %%
from tqdm.notebook import tqdm

# %%
def extract_features(images):
    features = []
    for image in tqdm(images):
        img = load_img(image,grayscale =  True )
        img = np.array(img)
        features.append(img)
    features = np.array(features)
    features = features.reshape(len(features),48,48,1)
    return features

# %%
train_features = extract_features(train['image'])
# Out:
#   0%|          | 0/28821 [00:00<?, ?it/s]
# C:\Users\dhanu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras_preprocessing\image\utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
test_features = extract_features(test['image'])
# Out:
#   0%|          | 0/7066 [00:00<?, ?it/s]

# %%
x_train = train_features/255.0
x_test = test_features/255.0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le.fit(train['label'])
# Out:
# LabelEncoder()

# %%
y_train = le.transform(train['label'])
y_test = le.transform(test['label'])

# %%
y_train = to_categorical(y_train,num_classes = 7)
y_test = to_categorical(y_test,num_classes = 7)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Input

# %%
model = Sequential()
# convolutional layers
model.add(Conv2D(128, kernel_size=(3,3), activation='relu', input_shape=(48,48,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(256, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Flatten())
# fully connected layers
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
# output layer
model.add(Dense(7, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x= x_train,y = y_train, batch_size = 128, epochs = 100, validation_data = (x_test,y_test))
# Out:
# Epoch 1/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 193s 844ms/step - accuracy: 0.2284 - loss: 1.8422 - val_accuracy: 0.2583 - val_loss: 1.8085
# Epoch 2/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 231s 1s/step - accuracy: 0.2500 - loss: 1.8065 - val_accuracy: 0.2607 - val_loss: 1.7708
# Epoch 3/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 249s 1s/step - accuracy: 0.2819 - loss: 1.7431 - val_accuracy: 0.3360 - val_loss: 1.6326
# Epoch 4/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 272s 1s/step - accuracy: 0.3299 - loss: 1.6656 - val_accuracy: 0.4178 - val_loss: 1.4842
# Epoch 5/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 270s 1s/step - accuracy: 0.3986 - loss: 1.5259 - val_accuracy: 0.4578 - val_loss: 1.3970
# Epoch 6/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 276s 1s/step - accuracy: 0.4393 - loss: 1.4487 - val_accuracy: 0.4894 - val_loss: 1.3208
# Epoch 7/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 276s 1s/step - accuracy: 0.4519 - loss: 1.4029 - val_accuracy: 0.5130 - val_loss: 1.2731
# Epoch 8/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 278s 1s/step - accuracy: 0.4676 - loss: 1.3747 - val_accuracy: 0.5119 - val_loss: 1.2768
# Epoch 9/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 280s 1s/step - accuracy: 0.4817 - loss: 1.3507 - val_accuracy: 0.5245 - val_loss: 1.2352
# Epoch 10/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 280s 1s/step - accuracy: 0.4960 - loss: 1.3182 - val_accuracy: 0.5487 - val_loss: 1.1981
# Epoch 11/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 281s 1s/step - accuracy: 0.5024 - loss: 1.2965 - val_accuracy: 0.5427 - val_loss: 1.2022
# Epoch 12/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 279s 1s/step - accuracy: 0.5146 - loss: 1.2747 - val_accuracy: 0.5563 - val_loss: 1.1766
# Epoch 13/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 277s 1s/step - accuracy: 0.5208 - loss: 1.2585 - val_accuracy: 0.5589 - val_loss: 1.1574
# Epoch 14/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 275s 1s/step - accuracy: 0.5246 - loss: 1.2533 - val_accuracy: 0.5695 - val_loss: 1.1496
# Epoch 15/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 272s 1s/step - accuracy: 0.5268 - loss: 1.2416 - val_accuracy: 0.5709 - val_loss: 1.1446
# Epoch 16/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.5335 - loss: 1.2362 - val_accuracy: 0.5651 - val_loss: 1.1458
# Epoch 17/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.5360 - loss: 1.2127 - val_accuracy: 0.5739 - val_loss: 1.1314
# Epoch 18/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 262s 1s/step - accuracy: 0.5344 - loss: 1.2156 - val_accuracy: 0.5751 - val_loss: 1.1267
# Epoch 19/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 259s 1s/step - accuracy: 0.5491 - loss: 1.1893 - val_accuracy: 0.5727 - val_loss: 1.1258
# Epoch 20/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 257s 1s/step - accuracy: 0.5494 - loss: 1.1816 - val_accuracy: 0.5793 - val_loss: 1.1133
# Epoch 21/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 256s 1s/step - accuracy: 0.5549 - loss: 1.1658 - val_accuracy: 0.5882 - val_loss: 1.1048
# Epoch 22/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 257s 1s/step - accuracy: 0.5568 - loss: 1.1647 - val_accuracy: 0.5807 - val_loss: 1.1157
# Epoch 23/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 257s 1s/step - accuracy: 0.5547 - loss: 1.1699 - val_accuracy: 0.5853 - val_loss: 1.1027
# Epoch 24/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 256s 1s/step - accuracy: 0.5680 - loss: 1.1497 - val_accuracy: 0.5900 - val_loss: 1.0950
# Epoch 25/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 257s 1s/step - accuracy: 0.5744 - loss: 1.1426 - val_accuracy: 0.5890 - val_loss: 1.0984
# Epoch 26/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 260s 1s/step - accuracy: 0.5724 - loss: 1.1317 - val_accuracy: 0.5834 - val_loss: 1.0988
# Epoch 27/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 257s 1s/step - accuracy: 0.5799 - loss: 1.1244 - val_accuracy: 0.5913 - val_loss: 1.0918
# Epoch 28/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 260s 1s/step - accuracy: 0.5811 - loss: 1.1110 - val_accuracy: 0.5879 - val_loss: 1.0822
# Epoch 29/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 257s 1s/step - accuracy: 0.5798 - loss: 1.1095 - val_accuracy: 0.5901 - val_loss: 1.0899
# Epoch 30/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 258s 1s/step - accuracy: 0.5778 - loss: 1.1176 - val_accuracy: 0.5948 - val_loss: 1.0710
# Epoch 31/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 257s 1s/step - accuracy: 0.5849 - loss: 1.0902 - val_accuracy: 0.5981 - val_loss: 1.0775
# Epoch 32/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 256s 1s/step - accuracy: 0.5942 - loss: 1.0856 - val_accuracy: 0.5974 - val_loss: 1.0676
# Epoch 33/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 251s 1s/step - accuracy: 0.5851 - loss: 1.0975 - val_accuracy: 0.5914 - val_loss: 1.0732
# Epoch 34/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 235s 1s/step - accuracy: 0.5917 - loss: 1.0831 - val_accuracy: 0.5969 - val_loss: 1.0630
# Epoch 35/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 235s 1s/step - accuracy: 0.5957 - loss: 1.0746 - val_accuracy: 0.6010 - val_loss: 1.0659
# Epoch 36/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 235s 1s/step - accuracy: 0.5941 - loss: 1.0701 - val_accuracy: 0.5958 - val_loss: 1.0742
# Epoch 37/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 235s 1s/step - accuracy: 0.5980 - loss: 1.0662 - val_accuracy: 0.6010 - val_loss: 1.0604
# Epoch 38/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 236s 1s/step - accuracy: 0.5985 - loss: 1.0624 - val_accuracy: 0.6032 - val_loss: 1.0550
# Epoch 39/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 235s 1s/step - accuracy: 0.6044 - loss: 1.0537 - val_accuracy: 0.6035 - val_loss: 1.0626
# Epoch 40/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 235s 1s/step - accuracy: 0.6045 - loss: 1.0457 - val_accuracy: 0.6050 - val_loss: 1.0666
# Epoch 41/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 234s 1s/step - accuracy: 0.6133 - loss: 1.0410 - val_accuracy: 0.6102 - val_loss: 1.0545
# Epoch 42/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 235s 1s/step - accuracy: 0.6136 - loss: 1.0369 - val_accuracy: 0.6076 - val_loss: 1.0643
# Epoch 43/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 240s 1s/step - accuracy: 0.6134 - loss: 1.0299 - val_accuracy: 0.6080 - val_loss: 1.0543
# Epoch 44/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 235s 1s/step - accuracy: 0.6150 - loss: 1.0296 - val_accuracy: 0.6066 - val_loss: 1.0572
# Epoch 45/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 241s 1s/step - accuracy: 0.6086 - loss: 1.0292 - val_accuracy: 0.6049 - val_loss: 1.0540
# Epoch 46/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 242s 1s/step - accuracy: 0.6230 - loss: 1.0065 - val_accuracy: 0.6132 - val_loss: 1.0463
# Epoch 47/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 244s 1s/step - accuracy: 0.6172 - loss: 1.0114 - val_accuracy: 0.6110 - val_loss: 1.0453
# Epoch 48/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 246s 1s/step - accuracy: 0.6248 - loss: 0.9993 - val_accuracy: 0.6108 - val_loss: 1.0432
# Epoch 49/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 241s 1s/step - accuracy: 0.6249 - loss: 1.0017 - val_accuracy: 0.6108 - val_loss: 1.0515
# Epoch 50/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 238s 1s/step - accuracy: 0.6289 - loss: 0.9921 - val_accuracy: 0.6165 - val_loss: 1.0461
# Epoch 51/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 238s 1s/step - accuracy: 0.6298 - loss: 0.9899 - val_accuracy: 0.6118 - val_loss: 1.0495
# Epoch 52/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 242s 1s/step - accuracy: 0.6311 - loss: 0.9828 - val_accuracy: 0.6139 - val_loss: 1.0513
# Epoch 53/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 243s 1s/step - accuracy: 0.6324 - loss: 0.9742 - val_accuracy: 0.6202 - val_loss: 1.0341
# Epoch 54/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 247s 1s/step - accuracy: 0.6303 - loss: 0.9800 - val_accuracy: 0.6187 - val_loss: 1.0328
# Epoch 55/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.6418 - loss: 0.9600 - val_accuracy: 0.6175 - val_loss: 1.0431
# Epoch 56/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 268s 1s/step - accuracy: 0.6386 - loss: 0.9662 - val_accuracy: 0.6091 - val_loss: 1.0564
# Epoch 57/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 270s 1s/step - accuracy: 0.6362 - loss: 0.9597 - val_accuracy: 0.6101 - val_loss: 1.0628
# Epoch 58/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 279s 1s/step - accuracy: 0.6426 - loss: 0.9599 - val_accuracy: 0.6141 - val_loss: 1.0431
# Epoch 59/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 246s 1s/step - accuracy: 0.6476 - loss: 0.9349 - val_accuracy: 0.6267 - val_loss: 1.0270
# Epoch 60/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 248s 1s/step - accuracy: 0.6464 - loss: 0.9421 - val_accuracy: 0.6223 - val_loss: 1.0360
# Epoch 61/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 250s 1s/step - accuracy: 0.6430 - loss: 0.9454 - val_accuracy: 0.6271 - val_loss: 1.0239
# Epoch 62/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 250s 1s/step - accuracy: 0.6514 - loss: 0.9404 - val_accuracy: 0.6202 - val_loss: 1.0416
# Epoch 63/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 0.6460 - loss: 0.9415 - val_accuracy: 0.6210 - val_loss: 1.0333
# Epoch 64/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 0.6517 - loss: 0.9213 - val_accuracy: 0.6278 - val_loss: 1.0309
# Epoch 65/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 256s 1s/step - accuracy: 0.6557 - loss: 0.9286 - val_accuracy: 0.6238 - val_loss: 1.0338
# Epoch 66/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 0.6588 - loss: 0.9121 - val_accuracy: 0.6291 - val_loss: 1.0338
# Epoch 67/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 251s 1s/step - accuracy: 0.6608 - loss: 0.9119 - val_accuracy: 0.6267 - val_loss: 1.0282
# Epoch 68/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 249s 1s/step - accuracy: 0.6583 - loss: 0.9157 - val_accuracy: 0.6275 - val_loss: 1.0346
# Epoch 69/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 248s 1s/step - accuracy: 0.6599 - loss: 0.9128 - val_accuracy: 0.6306 - val_loss: 1.0245
# Epoch 70/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 248s 1s/step - accuracy: 0.6651 - loss: 0.8895 - val_accuracy: 0.6211 - val_loss: 1.0451
# Epoch 71/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 247s 1s/step - accuracy: 0.6679 - loss: 0.8885 - val_accuracy: 0.6235 - val_loss: 1.0337
# Epoch 72/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 0.6718 - loss: 0.8903 - val_accuracy: 0.6224 - val_loss: 1.0313
# Epoch 73/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 248s 1s/step - accuracy: 0.6771 - loss: 0.8775 - val_accuracy: 0.6235 - val_loss: 1.0364
# Epoch 74/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 247s 1s/step - accuracy: 0.6646 - loss: 0.8994 - val_accuracy: 0.6213 - val_loss: 1.0416
# Epoch 75/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 249s 1s/step - accuracy: 0.6756 - loss: 0.8801 - val_accuracy: 0.6192 - val_loss: 1.0364
# Epoch 76/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 246s 1s/step - accuracy: 0.6741 - loss: 0.8815 - val_accuracy: 0.6211 - val_loss: 1.0380
# Epoch 77/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 248s 1s/step - accuracy: 0.6785 - loss: 0.8717 - val_accuracy: 0.6247 - val_loss: 1.0346
# Epoch 78/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 248s 1s/step - accuracy: 0.6764 - loss: 0.8764 - val_accuracy: 0.6241 - val_loss: 1.0320
# Epoch 79/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 248s 1s/step - accuracy: 0.6797 - loss: 0.8669 - val_accuracy: 0.6226 - val_loss: 1.0335
# Epoch 80/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 247s 1s/step - accuracy: 0.6774 - loss: 0.8607 - val_accuracy: 0.6295 - val_loss: 1.0317
# Epoch 81/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 245s 1s/step - accuracy: 0.6857 - loss: 0.8517 - val_accuracy: 0.6233 - val_loss: 1.0249
# Epoch 82/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 246s 1s/step - accuracy: 0.6839 - loss: 0.8583 - val_accuracy: 0.6248 - val_loss: 1.0463
# Epoch 83/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 245s 1s/step - accuracy: 0.6880 - loss: 0.8457 - val_accuracy: 0.6238 - val_loss: 1.0306
# Epoch 84/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 245s 1s/step - accuracy: 0.6843 - loss: 0.8488 - val_accuracy: 0.6234 - val_loss: 1.0366
# Epoch 85/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 246s 1s/step - accuracy: 0.6944 - loss: 0.8271 - val_accuracy: 0.6269 - val_loss: 1.0265
# Epoch 86/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 0.6859 - loss: 0.8561 - val_accuracy: 0.6353 - val_loss: 1.0256
# Epoch 87/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 247s 1s/step - accuracy: 0.6911 - loss: 0.8398 - val_accuracy: 0.6282 - val_loss: 1.0294
# Epoch 88/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 245s 1s/step - accuracy: 0.6924 - loss: 0.8344 - val_accuracy: 0.6289 - val_loss: 1.0203
# Epoch 89/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 245s 1s/step - accuracy: 0.6973 - loss: 0.8180 - val_accuracy: 0.6238 - val_loss: 1.0317
# Epoch 90/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 245s 1s/step - accuracy: 0.6975 - loss: 0.8119 - val_accuracy: 0.6306 - val_loss: 1.0333
# Epoch 91/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 244s 1s/step - accuracy: 0.6986 - loss: 0.8132 - val_accuracy: 0.6252 - val_loss: 1.0418
# Epoch 92/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 245s 1s/step - accuracy: 0.6948 - loss: 0.8119 - val_accuracy: 0.6268 - val_loss: 1.0368
# Epoch 93/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 245s 1s/step - accuracy: 0.7023 - loss: 0.8170 - val_accuracy: 0.6275 - val_loss: 1.0333
# Epoch 94/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 246s 1s/step - accuracy: 0.7071 - loss: 0.8077 - val_accuracy: 0.6278 - val_loss: 1.0278
# Epoch 95/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 246s 1s/step - accuracy: 0.7045 - loss: 0.8031 - val_accuracy: 0.6313 - val_loss: 1.0227
# Epoch 96/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 246s 1s/step - accuracy: 0.6957 - loss: 0.8171 - val_accuracy: 0.6303 - val_loss: 1.0271
# Epoch 97/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 246s 1s/step - accuracy: 0.7097 - loss: 0.7927 - val_accuracy: 0.6240 - val_loss: 1.0418
# Epoch 98/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 253s 1s/step - accuracy: 0.7131 - loss: 0.7874 - val_accuracy: 0.6320 - val_loss: 1.0423
# Epoch 99/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 253s 1s/step - accuracy: 0.7127 - loss: 0.7792 - val_accuracy: 0.6241 - val_loss: 1.0409
# Epoch 100/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 249s 1s/step - accuracy: 0.7124 - loss: 0.7758 - val_accuracy: 0.6269 - val_loss: 1.0359

# %%
model_json = model.to_json()
with open("emotiondetector.json",'w') as json_file:
    json_file.write(model_json)
model.save("emotiondetector.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from keras.models import model_from_json

# %%
json_file = open("emotiondetector.json", "r")
model_json = json_file.read()
json_file.close()
model = model_from_json(model_json)
model.load_weights("emotiondetector.h5")

# %%
label = ['angry','disgust','fear','happy','neutral','sad','surprise']

# %%
def ef(image):
    img = load_img(image,grayscale =  True )
    feature = np.array(img)
    feature = feature.reshape(1,48,48,1)
    return feature/255.0

# %%
image = 'images/train/sad/42.jpg'
print("original image is of sad")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
# Out:
# original image is of sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# model prediction is  sad
# C:\Users\dhanu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras_preprocessing\image\utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
